# %%
from joblib import dump,load
import numpy as np
model = load('Mining.joblib')

# %%
input = np.array([[ 0.04897149, -0.71268691,  2.65415157,  1.83030052, -1.48486139,
        2.07624191,  0.        , -0.41238947, -0.53583177,  3.86050692,
        0.28738295,  0.65944078,  0.70728041,  0.43580686,  0.21951743,
        0.26726249,  0.26673569,  2.38857631,  5.0160405 ,  4.06503796,
        0.80094284]])
model.predict(input)
# Out:
# array([4.0775])
